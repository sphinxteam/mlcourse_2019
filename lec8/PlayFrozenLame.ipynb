# %% [markdown]
# # Reinforcement learning approach to the Frowen lake game#
# ## A simple illustration of the q-learning algorithm ##
# We are going to teach a computer to play the Game "FROZEN LAKE" which, converniently enough, is provided by the gym environement:

# %%
import numpy as np
import gym
import random
env = gym.make("FrozenLake-v0")

# %% [markdown]
# The goal is the game is easy: one start at the top left of the screen, and needs to go down to the bottom right, avoiding the holes:
# ![](Frozen-Lake.png	)
# The player must deceide at each steps what he does, but beware, the lake is slipery, so even if you move left, from time to time you will find yourself moving in a different direction.
#
# As can be checked easyly, there are $4$ possible actions, and $16$ possible states:

# %%
action_size = env.action_space.n
state_size = env.observation_space.n
print("Number of possible actions: %d, number of possible states :%d." % (action_size,state_size))
# Out:
# Number of possible actions: 4, number of possible states :16.

# %% [markdown]
# Our goal will be to construct the Q-table that will give us, for each action, the total sum of reward in the future. In other words, the ideal table should be
# $$
# Q^*(s,a)=R^0(a)+\sum_{t=1}^{\infty} \gamma^t R^t
# $$
# where $R^0$ is the immediate reward if action $a$ is taken, and $R^t$ is the best possible reward for all next possible times.
#
# Since we do not know this table *a priori* we start with a random guess Q:

# %%
qtable = np.random.uniform(0,1e-4,(state_size, action_size))
print(qtable)
# Out:
# [[5.41539147e-05 6.45135836e-05 9.99345866e-05 9.56053158e-05]
#  [7.39872664e-05 8.83798262e-05 3.37386476e-05 1.53178718e-05]
#  [5.39711565e-05 2.19246452e-05 5.64527227e-05 5.17883291e-05]
#  [1.20104135e-05 7.79594597e-05 8.85171425e-05 4.01525437e-06]
#  [9.02156590e-05 6.13805809e-05 4.35008015e-05 2.05970442e-05]
#  [6.06962201e-05 4.44012672e-06 8.27955228e-05 7.90066548e-05]
#  [3.33795804e-05 5.39346444e-05 7.17801921e-05 5.35004512e-05]
#  [2.00275021e-05 9.41284244e-05 6.65067103e-06 9.71803796e-05]
#  [8.34723829e-05 6.84790231e-05 1.26095704e-05 8.92096394e-05]
#  [2.87734517e-05 8.53742732e-05 2.22162097e-05 7.83220851e-05]
#  [8.15326581e-05 6.80834863e-05 9.58550014e-05 9.18789001e-05]
#  [1.89245905e-05 3.16057691e-05 3.08893566e-05 2.58753445e-05]
#  [1.85428840e-05 1.60562820e-06 3.78284716e-05 4.58245846e-05]
#  [8.42544301e-05 5.10220873e-05 6.28623833e-07 5.77497402e-05]
#  [4.80812801e-05 8.44680549e-05 6.22223417e-05 1.70161679e-05]
#  [3.98306928e-05 5.64708631e-05 7.51717908e-05 5.82942569e-05]]

# %% [markdown]
# To learn this table (the Q-learning part) we need to derive the Bellman equation. It follows from the remark that for the ideal table one has:
# $$Q^*(s,a)=R^0(a)+\sum_{t=1}^{\infty} \gamma^t R^t= R^0(a) + \gamma \sum_{t=1}^{\infty} \gamma^{t-1} R^t = R^0(a) + \gamma \left[R^1  + \sum_{\tau=1}^{\infty} \gamma^{\tau} R^{1+\tau}\right]$$
#
# Since $Q^*(s,a)$ is time-translation invariant, we can thus write:
# $$Q^*(s,a)= R^0(a) + \gamma \left[R_{\rm best}^1  + \sum_{\tau=0}^{\infty} \gamma^{\tau} R^{1+\tau}\right]$$
# and this leads to the **Bellman equation**:
# $$Q^*(s,a)=  R^0(a) + \gamma \max_{a'} Q^*(s'|a,a')$$
#
# Given this identity, we will use the update rule:
# $$
# Q^{t+1}(s,a)=(1-\delta) * Q^{t}(s,a)+ \delta(R(a) * \gamma \max_{a'} Q^*(s'|a,a')$$
# where $\delta$ is the learning rate.
#
# The important point, before updating this table, is to set up an equilibrium between exploration and explotation when we play the game: of course, we want ultimatly to play the game according to the q-table $Q^*$ (*exploitation*) but since, at the begiging, our table $Q$ is essentially random, we should also try from to time to time to allow random moves (exploration).
#
# We shall do this less and less over time, of course, and every time we play a new game (a new episode) we should start to beleive more and more our table and so we shall set the eploration rate as
# $$
# \epsilon^t = \epsilon_{\min} + (\epsilon_{\max} - \epsilon_{\min})e^{-n_{\rm episode} \lambda}
# $$
# where $\lambda$ is a decay rate.
#
# Let us set up all these parameters

# %%
total_episodes = 20000      # Total episodes (number of games played)
learning_rate = 0.5         # Learning rate in Bellman equation (delta)
max_steps = 99              # Max steps per episode
gamma = 0.99                # Discounting rate in the Q-table

# Exploration parameters
epsilon = 1.0                 # Exploration rate
max_epsilon = 1.0             # Exploration probability at start
min_epsilon = 0.001            # Minimum exploration probability 
decay_rate = 0.001             # Exponential decay rate for exploration prob

# %% [markdown]
# We are now ready to write the learning algorithm:

# %%
# List of rewards
rewards = []

# For each episode/game, we play:
for episode in range(total_episodes):
    # Reset the environment
    state = env.reset()
    step = 0
    done = False
    total_rewards = 0
    
    #Now, we play until dead or until it became toooooooo long
    for step in range(max_steps):
        # First we deceide if we play in or out of policy:
        exp_exp_tradeoff = random.uniform(0, 1)
        ## If this number > greater than epsilon --> exploitation (taking the biggest Q value for this state)
        if exp_exp_tradeoff > epsilon:
            action = np.argmax(qtable[state,:])
        # Else doing a random choice --> exploration
        else:
            action = env.action_space.sample()

        # Now we take the action (a) and observe the outcome state(s') and reward (r)
        new_state, reward, done, info = env.step(action)

        # Finally we perform the Bellman update...
        qtable[state, action] = qtable[state, action] + learning_rate * (reward + gamma * np.max(qtable[new_state, :]) - qtable[state, action])
        #... and update the reward for this game.
        # Note that here, we only get a reward 1 if we eventually reach the goal!
        total_rewards += reward
        
        # Our new state is state
        state = new_state
        
        # If done (if we're dead) : finish episode
        if done == True: 
            break
        #other we continue to play
        
    # Reduce epsilon after each game/episode
    epsilon = min_epsilon + (max_epsilon - min_epsilon)*np.exp(-decay_rate*episode) 
    #update rewards
    rewards.append(total_rewards)
    
    if(episode%100==0):
        av_rewards=sum(rewards)/100;
        print("Game numer %d, epsilon=%f,  total reward:%f" %(episode,epsilon,av_rewards))
        rewards = []

print(qtable)
# Out:
# Game numer 0, epsilon=1.000000,  total reward:0.000000
# Game numer 100, epsilon=0.904933,  total reward:0.030000
# Game numer 200, epsilon=0.818912,  total reward:0.020000
# Game numer 300, epsilon=0.741077,  total reward:0.040000
# Game numer 400, epsilon=0.670650,  total reward:0.030000
# Game numer 500, epsilon=0.606924,  total reward:0.010000
# Game numer 600, epsilon=0.549263,  total reward:0.060000
# Game numer 700, epsilon=0.497089,  total reward:0.050000
# Game numer 800, epsilon=0.449880,  total reward:0.070000
# Game numer 900, epsilon=0.407163,  total reward:0.060000
# Game numer 1000, epsilon=0.368512,  total reward:0.110000
# Game numer 1100, epsilon=0.333538,  total reward:0.120000
# Game numer 1200, epsilon=0.301893,  total reward:0.050000
# Game numer 1300, epsilon=0.273259,  total reward:0.070000
# Game numer 1400, epsilon=0.247350,  total reward:0.170000
# Game numer 1500, epsilon=0.223907,  total reward:0.090000
# Game numer 1600, epsilon=0.202695,  total reward:0.150000
# Game numer 1700, epsilon=0.183501,  total reward:0.180000
# Game numer 1800, epsilon=0.166134,  total reward:0.230000
# Game numer 1900, epsilon=0.150419,  total reward:0.200000
# Game numer 2000, epsilon=0.136200,  total reward:0.230000
# Game numer 2100, epsilon=0.123334,  total reward:0.260000
# Game numer 2200, epsilon=0.111692,  total reward:0.220000
# Game numer 2300, epsilon=0.101159,  total reward:0.220000
# Game numer 2400, epsilon=0.091627,  total reward:0.350000
# Game numer 2500, epsilon=0.083003,  total reward:0.310000
# Game numer 2600, epsilon=0.075199,  total reward:0.290000
# Game numer 2700, epsilon=0.068138,  total reward:0.310000
# Game numer 2800, epsilon=0.061749,  total reward:0.330000
# Game numer 2900, epsilon=0.055968,  total reward:0.280000
# Game numer 3000, epsilon=0.050737,  total reward:0.430000
# Game numer 3100, epsilon=0.046004,  total reward:0.530000
# Game numer 3200, epsilon=0.041721,  total reward:0.260000
# Game numer 3300, epsilon=0.037846,  total reward:0.390000
# Game numer 3400, epsilon=0.034340,  total reward:0.440000
# Game numer 3500, epsilon=0.031167,  total reward:0.460000
# Game numer 3600, epsilon=0.028296,  total reward:0.470000
# Game numer 3700, epsilon=0.025699,  total reward:0.570000
# Game numer 3800, epsilon=0.023348,  total reward:0.540000
# Game numer 3900, epsilon=0.021222,  total reward:0.540000
# Game numer 4000, epsilon=0.019297,  total reward:0.480000
# Game numer 4100, epsilon=0.017556,  total reward:0.630000
# Game numer 4200, epsilon=0.015981,  total reward:0.620000
# Game numer 4300, epsilon=0.014555,  total reward:0.420000
# Game numer 4400, epsilon=0.013265,  total reward:0.600000
# Game numer 4500, epsilon=0.012098,  total reward:0.640000
# Game numer 4600, epsilon=0.011042,  total reward:0.460000
# Game numer 4700, epsilon=0.010086,  total reward:0.460000
# Game numer 4800, epsilon=0.009222,  total reward:0.540000
# Game numer 4900, epsilon=0.008439,  total reward:0.650000
# Game numer 5000, epsilon=0.007731,  total reward:0.620000
# Game numer 5100, epsilon=0.007091,  total reward:0.680000
# Game numer 5200, epsilon=0.006511,  total reward:0.630000
# Game numer 5300, epsilon=0.005987,  total reward:0.610000
# Game numer 5400, epsilon=0.005512,  total reward:0.660000
# Game numer 5500, epsilon=0.005083,  total reward:0.730000
# Game numer 5600, epsilon=0.004694,  total reward:0.720000
# Game numer 5700, epsilon=0.004343,  total reward:0.600000
# Game numer 5800, epsilon=0.004025,  total reward:0.660000
# Game numer 5900, epsilon=0.003737,  total reward:0.690000
# Game numer 6000, epsilon=0.003476,  total reward:0.440000
# Game numer 6100, epsilon=0.003241,  total reward:0.650000
# Game numer 6200, epsilon=0.003027,  total reward:0.750000
# Game numer 6300, epsilon=0.002834,  total reward:0.700000
# Game numer 6400, epsilon=0.002660,  total reward:0.610000
# Game numer 6500, epsilon=0.002502,  total reward:0.680000
# Game numer 6600, epsilon=0.002359,  total reward:0.730000
# Game numer 6700, epsilon=0.002230,  total reward:0.450000
# Game numer 6800, epsilon=0.002113,  total reward:0.670000
# Game numer 6900, epsilon=0.002007,  total reward:0.750000
# Game numer 7000, epsilon=0.001911,  total reward:0.770000
# Game numer 7100, epsilon=0.001824,  total reward:0.720000
# Game numer 7200, epsilon=0.001746,  total reward:0.680000
# Game numer 7300, epsilon=0.001675,  total reward:0.720000
# Game numer 7400, epsilon=0.001611,  total reward:0.640000
# Game numer 7500, epsilon=0.001553,  total reward:0.730000
# Game numer 7600, epsilon=0.001500,  total reward:0.700000
# Game numer 7700, epsilon=0.001452,  total reward:0.750000
# Game numer 7800, epsilon=0.001409,  total reward:0.800000
# Game numer 7900, epsilon=0.001370,  total reward:0.710000
# Game numer 8000, epsilon=0.001335,  total reward:0.650000
# Game numer 8100, epsilon=0.001303,  total reward:0.660000
# Game numer 8200, epsilon=0.001274,  total reward:0.550000
# Game numer 8300, epsilon=0.001248,  total reward:0.660000
# Game numer 8400, epsilon=0.001225,  total reward:0.580000
# Game numer 8500, epsilon=0.001203,  total reward:0.730000
# Game numer 8600, epsilon=0.001184,  total reward:0.670000
# Game numer 8700, epsilon=0.001166,  total reward:0.670000
# Game numer 8800, epsilon=0.001151,  total reward:0.680000
# Game numer 8900, epsilon=0.001136,  total reward:0.640000
# Game numer 9000, epsilon=0.001123,  total reward:0.730000
# Game numer 9100, epsilon=0.001112,  total reward:0.560000
# Game numer 9200, epsilon=0.001101,  total reward:0.740000
# Game numer 9300, epsilon=0.001091,  total reward:0.810000
# Game numer 9400, epsilon=0.001083,  total reward:0.790000
# Game numer 9500, epsilon=0.001075,  total reward:0.650000
# Game numer 9600, epsilon=0.001068,  total reward:0.650000
# Game numer 9700, epsilon=0.001061,  total reward:0.820000
# Game numer 9800, epsilon=0.001055,  total reward:0.780000
# Game numer 9900, epsilon=0.001050,  total reward:0.620000
# Game numer 10000, epsilon=0.001045,  total reward:0.640000
# Game numer 10100, epsilon=0.001041,  total reward:0.740000
# Game numer 10200, epsilon=0.001037,  total reward:0.650000
# Game numer 10300, epsilon=0.001034,  total reward:0.750000
# Game numer 10400, epsilon=0.001030,  total reward:0.610000
# Game numer 10500, epsilon=0.001028,  total reward:0.750000
# Game numer 10600, epsilon=0.001025,  total reward:0.790000
# Game numer 10700, epsilon=0.001023,  total reward:0.730000
# Game numer 10800, epsilon=0.001020,  total reward:0.700000
# Game numer 10900, epsilon=0.001018,  total reward:0.810000
# Game numer 11000, epsilon=0.001017,  total reward:0.750000
# Game numer 11100, epsilon=0.001015,  total reward:0.710000
# Game numer 11200, epsilon=0.001014,  total reward:0.740000
# Game numer 11300, epsilon=0.001012,  total reward:0.750000
# Game numer 11400, epsilon=0.001011,  total reward:0.660000
# Game numer 11500, epsilon=0.001010,  total reward:0.750000
# Game numer 11600, epsilon=0.001009,  total reward:0.720000
# Game numer 11700, epsilon=0.001008,  total reward:0.680000
# Game numer 11800, epsilon=0.001007,  total reward:0.790000
# Game numer 11900, epsilon=0.001007,  total reward:0.780000
# Game numer 12000, epsilon=0.001006,  total reward:0.750000
# Game numer 12100, epsilon=0.001006,  total reward:0.760000
# Game numer 12200, epsilon=0.001005,  total reward:0.700000
# Game numer 12300, epsilon=0.001005,  total reward:0.740000
# Game numer 12400, epsilon=0.001004,  total reward:0.680000
# Game numer 12500, epsilon=0.001004,  total reward:0.800000
# Game numer 12600, epsilon=0.001003,  total reward:0.680000
# Game numer 12700, epsilon=0.001003,  total reward:0.640000
# Game numer 12800, epsilon=0.001003,  total reward:0.690000
# Game numer 12900, epsilon=0.001002,  total reward:0.700000
# Game numer 13000, epsilon=0.001002,  total reward:0.730000
# Game numer 13100, epsilon=0.001002,  total reward:0.630000
# Game numer 13200, epsilon=0.001002,  total reward:0.600000
# Game numer 13300, epsilon=0.001002,  total reward:0.710000
# Game numer 13400, epsilon=0.001002,  total reward:0.770000
# Game numer 13500, epsilon=0.001001,  total reward:0.790000
# Game numer 13600, epsilon=0.001001,  total reward:0.720000
# Game numer 13700, epsilon=0.001001,  total reward:0.630000
# Game numer 13800, epsilon=0.001001,  total reward:0.800000
# Game numer 13900, epsilon=0.001001,  total reward:0.740000
# Game numer 14000, epsilon=0.001001,  total reward:0.700000
# Game numer 14100, epsilon=0.001001,  total reward:0.670000
# Game numer 14200, epsilon=0.001001,  total reward:0.750000
# Game numer 14300, epsilon=0.001001,  total reward:0.770000
# Game numer 14400, epsilon=0.001001,  total reward:0.710000
# Game numer 14500, epsilon=0.001001,  total reward:0.780000
# Game numer 14600, epsilon=0.001000,  total reward:0.680000
# Game numer 14700, epsilon=0.001000,  total reward:0.590000
# Game numer 14800, epsilon=0.001000,  total reward:0.610000
# Game numer 14900, epsilon=0.001000,  total reward:0.790000
# Game numer 15000, epsilon=0.001000,  total reward:0.800000
# Game numer 15100, epsilon=0.001000,  total reward:0.610000
# Game numer 15200, epsilon=0.001000,  total reward:0.620000
# Game numer 15300, epsilon=0.001000,  total reward:0.550000
# Game numer 15400, epsilon=0.001000,  total reward:0.610000
# Game numer 15500, epsilon=0.001000,  total reward:0.700000
# Game numer 15600, epsilon=0.001000,  total reward:0.740000
# Game numer 15700, epsilon=0.001000,  total reward:0.680000
# Game numer 15800, epsilon=0.001000,  total reward:0.720000
# Game numer 15900, epsilon=0.001000,  total reward:0.600000
# Game numer 16000, epsilon=0.001000,  total reward:0.610000
# Game numer 16100, epsilon=0.001000,  total reward:0.540000
# Game numer 16200, epsilon=0.001000,  total reward:0.690000
# Game numer 16300, epsilon=0.001000,  total reward:0.760000
# Game numer 16400, epsilon=0.001000,  total reward:0.640000
# Game numer 16500, epsilon=0.001000,  total reward:0.780000
# Game numer 16600, epsilon=0.001000,  total reward:0.770000
# Game numer 16700, epsilon=0.001000,  total reward:0.720000
# Game numer 16800, epsilon=0.001000,  total reward:0.730000
# Game numer 16900, epsilon=0.001000,  total reward:0.750000
# Game numer 17000, epsilon=0.001000,  total reward:0.760000
# Game numer 17100, epsilon=0.001000,  total reward:0.770000
# Game numer 17200, epsilon=0.001000,  total reward:0.650000
# Game numer 17300, epsilon=0.001000,  total reward:0.710000
# Game numer 17400, epsilon=0.001000,  total reward:0.710000
# Game numer 17500, epsilon=0.001000,  total reward:0.660000
# Game numer 17600, epsilon=0.001000,  total reward:0.730000
# Game numer 17700, epsilon=0.001000,  total reward:0.760000
# Game numer 17800, epsilon=0.001000,  total reward:0.810000
# Game numer 17900, epsilon=0.001000,  total reward:0.690000
# Game numer 18000, epsilon=0.001000,  total reward:0.730000
# Game numer 18100, epsilon=0.001000,  total reward:0.720000
# Game numer 18200, epsilon=0.001000,  total reward:0.680000
# Game numer 18300, epsilon=0.001000,  total reward:0.780000
# Game numer 18400, epsilon=0.001000,  total reward:0.690000
# Game numer 18500, epsilon=0.001000,  total reward:0.770000
# Game numer 18600, epsilon=0.001000,  total reward:0.700000
# Game numer 18700, epsilon=0.001000,  total reward:0.830000
# Game numer 18800, epsilon=0.001000,  total reward:0.710000
# Game numer 18900, epsilon=0.001000,  total reward:0.780000
# Game numer 19000, epsilon=0.001000,  total reward:0.630000
# Game numer 19100, epsilon=0.001000,  total reward:0.610000
# Game numer 19200, epsilon=0.001000,  total reward:0.730000
# Game numer 19300, epsilon=0.001000,  total reward:0.730000
# Game numer 19400, epsilon=0.001000,  total reward:0.740000
# Game numer 19500, epsilon=0.001000,  total reward:0.690000
# Game numer 19600, epsilon=0.001000,  total reward:0.720000
# Game numer 19700, epsilon=0.001000,  total reward:0.640000
# Game numer 19800, epsilon=0.001000,  total reward:0.820000
# Game numer 19900, epsilon=0.001000,  total reward:0.750000
# [[6.46858460e-01 3.80072476e-01 3.87007405e-01 3.88604129e-01]
#  [1.30436096e-01 1.14209004e-01 1.08274351e-01 5.80412693e-01]
#  [1.97720659e-01 1.50098400e-01 1.12930476e-01 4.79515628e-01]
#  [1.80047166e-01 1.78609323e-01 1.42666883e-01 4.02461742e-01]
#  [6.95774174e-01 3.91614221e-01 1.21276443e-01 3.48771447e-01]
#  [6.06962201e-05 4.44012672e-06 8.27955228e-05 7.90066548e-05]
#  [3.14249408e-03 4.29436834e-04 4.97839300e-01 3.21244250e-02]
#  [2.00275021e-05 9.41284244e-05 6.65067103e-06 9.71803796e-05]
#  [2.22634026e-01 2.62387411e-01 2.23621495e-01 7.12766894e-01]
#  [4.19507572e-02 7.69298466e-01 1.22034851e-01 2.02462158e-01]
#  [5.83121302e-01 9.40916237e-02 5.30818158e-02 1.21726735e-02]
#  [1.89245905e-05 3.16057691e-05 3.08893566e-05 2.58753445e-05]
#  [1.85428840e-05 1.60562820e-06 3.78284716e-05 4.58245846e-05]
#  [1.34505018e-01 3.10997002e-01 9.33077706e-01 4.92479755e-01]
#  [4.93657603e-01 9.73699300e-01 3.73657435e-01 5.40336645e-01]
#  [3.98306928e-05 5.64708631e-05 7.51717908e-05 5.82942569e-05]]

# %% [markdown]
# We can now watch our little q-table playing the game, this time using *in policty* moves only:

# %%
env.reset()
env.render()
for step in range(max_steps):
    print ("t=%d " % (step))
    # Take the action (index) that have the maximum expected future reward given that state
    action = np.argmax(qtable[state,:])
    new_state, reward, done, info = env.step(action)
    if done:
        env.render()            
        # We print the number of step it took.
        print("Number of steps", step)
        break
    #else we move    
    state = new_state
    env.render()
# Out:
# SFFF
# FHFH
# FFFH
# HFFG
# t=0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# t=1
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=2
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=3
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=4
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=5
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=6
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=7
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=8
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=9
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=10
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=11
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=12
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# t=13
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=14
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# t=15
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=16
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# t=17
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=18
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=19
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=20
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=21
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=22
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=23
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=24
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=25
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=26
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=27
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=28
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=29
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=30
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=31
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=32
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=33
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=34
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=35
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=36
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=37
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=38
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=39
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=40
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=41
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=42
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=43
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=44
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=45
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=46
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=47
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=48
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=49
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=50
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=51
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=52
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=53
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=54
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=55
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=56
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=57
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=58
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=59
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=60
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=61
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=62
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=63
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=64
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=65
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=66
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=67
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=68
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=69
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=70
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=71
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# t=72
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=73
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=74
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=75
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# t=76
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# t=77
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# t=78
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Number of steps 78

# %% [markdown]
# Playing the parameters, we should be able to make an algortihm quite capable to play the game
