# %% [markdown]
# # Reinforcement learning approach to the Frozen lake game#
# ## A simple illustration of the q-learning algorithm ##
# We are going to teach a computer to play the Game "FROZEN LAKE" which, converniently enough, is provided by the gym environement:

# %%
import numpy as np
import gym
import random
env = gym.make("FrozenLake-v0")

# %% [markdown]
# The goal is the game is easy: one start at the top left of the screen, and needs to go down to the bottom right, avoiding the holes:
# ![](Frozen-Lake.png	)
# The player must decide at each step what he does, but beware, the lake is slipery, so even if you move left, from time to time you will find yourself moving in a different direction.
#
# As can be checked easyly, there are $4$ possible actions, and $16$ possible states:

# %%
action_size = env.action_space.n
state_size = env.observation_space.n
print("Number of possible actions: %d, number of possible states :%d." % (action_size,state_size))
# Out:
# Number of possible actions: 4, number of possible states :16.

# %% [markdown]
# Our goal will be to construct the Q-table that will give us, for each action, the total sum of reward in the future. In other words, the ideal table should be
# $$
# Q^*(s,a)=R^0(a)+\sum_{t=1}^{\infty} \gamma^t R^t
# $$
# where $R^0$ is the immediate reward if action $a$ is taken, and $R^t$ is the best possible reward for all next possible times.
#
# Since we do not know this table *a priori* we start with a random guess Q:

# %%
qtable = np.random.uniform(0,1e-4,(state_size, action_size))
print(qtable)
# Out:
# [[2.23373536e-05 9.53030158e-05 8.95416017e-05 6.67212136e-05]
#  [6.37936388e-05 5.36921572e-05 5.81251633e-05 1.14374951e-05]
#  [6.35668159e-05 4.66022420e-05 1.59235050e-05 7.21301648e-05]
#  [3.91223360e-05 2.69637943e-05 5.47249711e-06 6.32151651e-05]
#  [7.11248386e-05 4.48782366e-05 9.37446329e-05 6.05084050e-05]
#  [6.80195147e-05 6.98881962e-06 8.28213306e-05 7.79682486e-06]
#  [7.96609453e-05 1.50792366e-05 2.90486844e-05 3.53425389e-05]
#  [2.53335290e-05 8.53179739e-05 8.39578114e-06 4.90978506e-06]
#  [2.93531871e-05 3.03221281e-05 3.66774591e-05 6.14993506e-05]
#  [5.99103996e-05 4.91679620e-05 6.30646577e-05 6.03383140e-05]
#  [1.89577306e-05 7.13617019e-05 5.22561255e-05 4.81692791e-05]
#  [1.65522189e-05 2.77649000e-06 9.70695996e-05 7.15228114e-05]
#  [7.50908402e-05 7.08843014e-05 9.41159714e-05 2.91452041e-06]
#  [2.51453352e-05 3.12565910e-05 3.99746151e-05 5.72117333e-05]
#  [2.51211832e-05 9.69122843e-06 5.74488511e-05 2.32887949e-05]
#  [1.39831530e-06 3.16944752e-05 4.25885418e-05 6.78702678e-05]]

# %% [markdown]
# To learn this table (the Q-learning part) we need to derive the Bellman equation. It follows from the remark that for the ideal table one has:
# $$Q^*(s,a)=R^0(a)+\sum_{t=1}^{\infty} \gamma^t R^t= R^0(a) + \gamma \sum_{t=1}^{\infty} \gamma^{t-1} R^t = R^0(a) + \gamma \left[R^1  + \sum_{\tau=1}^{\infty} \gamma^{\tau} R^{1+\tau}\right]$$
#
# Since $Q^*(s,a)$ is time-translation invariant, we can thus write:
# $$Q^*(s,a)= R^0(a) + \gamma \left[R_{\rm best}^1  + \sum_{\tau=0}^{\infty} \gamma^{\tau} R^{1+\tau}\right]$$
# and this leads to the **Bellman equation**:
# $$Q^*(s,a)=  R^0(a) + \gamma \max_{a'} Q^*(s'|a,a')$$
#
# Given this identity, we will use the update rule:
# $$
# Q^{t+1}(s,a)=(1-\delta) * Q^{t}(s,a)+ \delta(R(a) * \gamma \max_{a'} Q^*(s'|a,a')$$
# where $\delta$ is the learning rate.
#
# The important point, before updating this table, is to set up an equilibrium between exploration and exploitation when we play the game: of course, we want ultimatly to play the game according to the q-table $Q^*$ (*exploitation*) but since, at the begiging, our table $Q$ is essentially random, we should also try from to time to time to allow random moves (exploration).
#
# We shall do this less and less over time, of course, and every time we play a new game (a new episode) we should start to believe more and more our table and so we shall set the exploration rate as
# $$
# \epsilon^t = \epsilon_{\min} + (\epsilon_{\max} - \epsilon_{\min})e^{-n_{\rm episode} \lambda}
# $$
# where $\lambda$ is a decay rate.
#
# Let us set up all these parameters

# %%
total_episodes = 20000      # Total episodes (number of games played)
learning_rate = 0.5         # Learning rate in Bellman equation (delta)
max_steps = 99              # Max steps per episode
gamma = 0.99                # Discounting rate in the Q-table

# Exploration parameters
epsilon = 1.0                 # Exploration rate
max_epsilon = 1.0             # Exploration probability at start
min_epsilon = 0.001            # Minimum exploration probability 
decay_rate = 0.001             # Exponential decay rate for exploration prob

# %% [markdown]
# We are now ready to write the learning algorithm:

# %%
# List of rewards
rewards = []

# For each episode/game, we play:
for episode in range(total_episodes):
    # Reset the environment
    state = env.reset()
    step = 0
    done = False
    total_rewards = 0
    
    #Now, we play until dead or until it became toooooooo long
    for step in range(max_steps):
        # First we decide if we play in or out of policy:
        exp_exp_tradeoff = random.uniform(0, 1)
        # If this number > greater than epsilon --> exploitation (taking the biggest Q value for this state)
        if exp_exp_tradeoff > epsilon:
            action = np.argmax(qtable[state,:])
        # Else doing a random choice --> exploration
        else:
            action = env.action_space.sample()

        # Now we take the action (a) and observe the outcome state(s') and reward (r)
        new_state, reward, done, info = env.step(action)

        # Finally we perform the Bellman update...
        qtable[state, action] = qtable[state, action] + learning_rate * (reward + gamma * np.max(qtable[new_state, :]) - qtable[state, action])
        #... and update the reward for this game.
        # Note that here, we only get a reward 1 if we eventually reach the goal!
        total_rewards += reward
        
        # Our new state is state
        state = new_state
        
        # If done (if we're dead) : finish episode
        if done == True: 
            break
        # otherwise we continue to play
        
    # Reduce epsilon after each game/episode
    epsilon = min_epsilon + (max_epsilon - min_epsilon)*np.exp(-decay_rate*episode) 
    # update rewards
    rewards.append(total_rewards)
    
    if(episode%100==0):
        av_rewards=sum(rewards)/100;
        print("Game numer %d, epsilon=%f,  total reward:%f" %(episode,epsilon,av_rewards))
        rewards = []

print(qtable)
# Out:
# Game numer 0, epsilon=1.000000,  total reward:0.000000
# Game numer 100, epsilon=0.904933,  total reward:0.010000
# Game numer 200, epsilon=0.818912,  total reward:0.020000
# Game numer 300, epsilon=0.741077,  total reward:0.000000
# Game numer 400, epsilon=0.670650,  total reward:0.030000
# Game numer 500, epsilon=0.606924,  total reward:0.010000
# Game numer 600, epsilon=0.549263,  total reward:0.060000
# Game numer 700, epsilon=0.497089,  total reward:0.030000
# Game numer 800, epsilon=0.449880,  total reward:0.050000
# Game numer 900, epsilon=0.407163,  total reward:0.090000
# Game numer 1000, epsilon=0.368512,  total reward:0.100000
# Game numer 1100, epsilon=0.333538,  total reward:0.060000
# Game numer 1200, epsilon=0.301893,  total reward:0.070000
# Game numer 1300, epsilon=0.273259,  total reward:0.150000
# Game numer 1400, epsilon=0.247350,  total reward:0.050000
# Game numer 1500, epsilon=0.223907,  total reward:0.140000
# Game numer 1600, epsilon=0.202695,  total reward:0.150000
# Game numer 1700, epsilon=0.183501,  total reward:0.170000
# Game numer 1800, epsilon=0.166134,  total reward:0.250000
# Game numer 1900, epsilon=0.150419,  total reward:0.090000
# Game numer 2000, epsilon=0.136200,  total reward:0.300000
# Game numer 2100, epsilon=0.123334,  total reward:0.290000
# Game numer 2200, epsilon=0.111692,  total reward:0.280000
# Game numer 2300, epsilon=0.101159,  total reward:0.270000
# Game numer 2400, epsilon=0.091627,  total reward:0.310000
# Game numer 2500, epsilon=0.083003,  total reward:0.400000
# Game numer 2600, epsilon=0.075199,  total reward:0.340000
# Game numer 2700, epsilon=0.068138,  total reward:0.300000
# Game numer 2800, epsilon=0.061749,  total reward:0.390000
# Game numer 2900, epsilon=0.055968,  total reward:0.310000
# Game numer 3000, epsilon=0.050737,  total reward:0.510000
# Game numer 3100, epsilon=0.046004,  total reward:0.390000
# Game numer 3200, epsilon=0.041721,  total reward:0.380000
# Game numer 3300, epsilon=0.037846,  total reward:0.310000
# Game numer 3400, epsilon=0.034340,  total reward:0.400000
# Game numer 3500, epsilon=0.031167,  total reward:0.360000
# Game numer 3600, epsilon=0.028296,  total reward:0.400000
# Game numer 3700, epsilon=0.025699,  total reward:0.490000
# Game numer 3800, epsilon=0.023348,  total reward:0.660000
# Game numer 3900, epsilon=0.021222,  total reward:0.520000
# Game numer 4000, epsilon=0.019297,  total reward:0.550000
# Game numer 4100, epsilon=0.017556,  total reward:0.600000
# Game numer 4200, epsilon=0.015981,  total reward:0.560000
# Game numer 4300, epsilon=0.014555,  total reward:0.450000
# Game numer 4400, epsilon=0.013265,  total reward:0.610000
# Game numer 4500, epsilon=0.012098,  total reward:0.510000
# Game numer 4600, epsilon=0.011042,  total reward:0.740000
# Game numer 4700, epsilon=0.010086,  total reward:0.590000
# Game numer 4800, epsilon=0.009222,  total reward:0.480000
# Game numer 4900, epsilon=0.008439,  total reward:0.510000
# Game numer 5000, epsilon=0.007731,  total reward:0.570000
# Game numer 5100, epsilon=0.007091,  total reward:0.580000
# Game numer 5200, epsilon=0.006511,  total reward:0.690000
# Game numer 5300, epsilon=0.005987,  total reward:0.570000
# Game numer 5400, epsilon=0.005512,  total reward:0.780000
# Game numer 5500, epsilon=0.005083,  total reward:0.590000
# Game numer 5600, epsilon=0.004694,  total reward:0.750000
# Game numer 5700, epsilon=0.004343,  total reward:0.720000
# Game numer 5800, epsilon=0.004025,  total reward:0.750000
# Game numer 5900, epsilon=0.003737,  total reward:0.670000
# Game numer 6000, epsilon=0.003476,  total reward:0.530000
# Game numer 6100, epsilon=0.003241,  total reward:0.730000
# Game numer 6200, epsilon=0.003027,  total reward:0.710000
# Game numer 6300, epsilon=0.002834,  total reward:0.710000
# Game numer 6400, epsilon=0.002660,  total reward:0.620000
# Game numer 6500, epsilon=0.002502,  total reward:0.680000
# Game numer 6600, epsilon=0.002359,  total reward:0.540000
# Game numer 6700, epsilon=0.002230,  total reward:0.710000
# Game numer 6800, epsilon=0.002113,  total reward:0.670000
# Game numer 6900, epsilon=0.002007,  total reward:0.720000
# Game numer 7000, epsilon=0.001911,  total reward:0.700000
# Game numer 7100, epsilon=0.001824,  total reward:0.620000
# Game numer 7200, epsilon=0.001746,  total reward:0.710000
# Game numer 7300, epsilon=0.001675,  total reward:0.680000
# Game numer 7400, epsilon=0.001611,  total reward:0.730000
# Game numer 7500, epsilon=0.001553,  total reward:0.660000
# Game numer 7600, epsilon=0.001500,  total reward:0.740000
# Game numer 7700, epsilon=0.001452,  total reward:0.690000
# Game numer 7800, epsilon=0.001409,  total reward:0.740000
# Game numer 7900, epsilon=0.001370,  total reward:0.670000
# Game numer 8000, epsilon=0.001335,  total reward:0.600000
# Game numer 8100, epsilon=0.001303,  total reward:0.730000
# Game numer 8200, epsilon=0.001274,  total reward:0.740000
# Game numer 8300, epsilon=0.001248,  total reward:0.680000
# Game numer 8400, epsilon=0.001225,  total reward:0.670000
# Game numer 8500, epsilon=0.001203,  total reward:0.810000
# Game numer 8600, epsilon=0.001184,  total reward:0.700000
# Game numer 8700, epsilon=0.001166,  total reward:0.750000
# Game numer 8800, epsilon=0.001151,  total reward:0.640000
# Game numer 8900, epsilon=0.001136,  total reward:0.700000
# Game numer 9000, epsilon=0.001123,  total reward:0.660000
# Game numer 9100, epsilon=0.001112,  total reward:0.680000
# Game numer 9200, epsilon=0.001101,  total reward:0.810000
# Game numer 9300, epsilon=0.001091,  total reward:0.680000
# Game numer 9400, epsilon=0.001083,  total reward:0.660000
# Game numer 9500, epsilon=0.001075,  total reward:0.610000
# Game numer 9600, epsilon=0.001068,  total reward:0.760000
# Game numer 9700, epsilon=0.001061,  total reward:0.830000
# Game numer 9800, epsilon=0.001055,  total reward:0.700000
# Game numer 9900, epsilon=0.001050,  total reward:0.750000
# Game numer 10000, epsilon=0.001045,  total reward:0.740000
# Game numer 10100, epsilon=0.001041,  total reward:0.630000
# Game numer 10200, epsilon=0.001037,  total reward:0.690000
# Game numer 10300, epsilon=0.001034,  total reward:0.740000
# Game numer 10400, epsilon=0.001030,  total reward:0.640000
# Game numer 10500, epsilon=0.001028,  total reward:0.690000
# Game numer 10600, epsilon=0.001025,  total reward:0.810000
# Game numer 10700, epsilon=0.001023,  total reward:0.720000
# Game numer 10800, epsilon=0.001020,  total reward:0.580000
# Game numer 10900, epsilon=0.001018,  total reward:0.780000
# Game numer 11000, epsilon=0.001017,  total reward:0.680000
# Game numer 11100, epsilon=0.001015,  total reward:0.660000
# Game numer 11200, epsilon=0.001014,  total reward:0.740000
# Game numer 11300, epsilon=0.001012,  total reward:0.710000
# Game numer 11400, epsilon=0.001011,  total reward:0.840000
# Game numer 11500, epsilon=0.001010,  total reward:0.720000
# Game numer 11600, epsilon=0.001009,  total reward:0.740000
# Game numer 11700, epsilon=0.001008,  total reward:0.680000
# Game numer 11800, epsilon=0.001007,  total reward:0.720000
# Game numer 11900, epsilon=0.001007,  total reward:0.630000
# Game numer 12000, epsilon=0.001006,  total reward:0.700000
# Game numer 12100, epsilon=0.001006,  total reward:0.710000
# Game numer 12200, epsilon=0.001005,  total reward:0.690000
# Game numer 12300, epsilon=0.001005,  total reward:0.640000
# Game numer 12400, epsilon=0.001004,  total reward:0.730000
# Game numer 12500, epsilon=0.001004,  total reward:0.700000
# Game numer 12600, epsilon=0.001003,  total reward:0.630000
# Game numer 12700, epsilon=0.001003,  total reward:0.730000
# Game numer 12800, epsilon=0.001003,  total reward:0.710000
# Game numer 12900, epsilon=0.001002,  total reward:0.770000
# Game numer 13000, epsilon=0.001002,  total reward:0.690000
# Game numer 13100, epsilon=0.001002,  total reward:0.650000
# Game numer 13200, epsilon=0.001002,  total reward:0.720000
# Game numer 13300, epsilon=0.001002,  total reward:0.690000
# Game numer 13400, epsilon=0.001002,  total reward:0.710000
# Game numer 13500, epsilon=0.001001,  total reward:0.660000
# Game numer 13600, epsilon=0.001001,  total reward:0.700000
# Game numer 13700, epsilon=0.001001,  total reward:0.700000
# Game numer 13800, epsilon=0.001001,  total reward:0.700000
# Game numer 13900, epsilon=0.001001,  total reward:0.780000
# Game numer 14000, epsilon=0.001001,  total reward:0.680000
# Game numer 14100, epsilon=0.001001,  total reward:0.800000
# Game numer 14200, epsilon=0.001001,  total reward:0.750000
# Game numer 14300, epsilon=0.001001,  total reward:0.750000
# Game numer 14400, epsilon=0.001001,  total reward:0.790000
# Game numer 14500, epsilon=0.001001,  total reward:0.580000
# Game numer 14600, epsilon=0.001000,  total reward:0.750000
# Game numer 14700, epsilon=0.001000,  total reward:0.680000
# Game numer 14800, epsilon=0.001000,  total reward:0.770000
# Game numer 14900, epsilon=0.001000,  total reward:0.760000
# Game numer 15000, epsilon=0.001000,  total reward:0.690000
# Game numer 15100, epsilon=0.001000,  total reward:0.640000
# Game numer 15200, epsilon=0.001000,  total reward:0.750000
# Game numer 15300, epsilon=0.001000,  total reward:0.710000
# Game numer 15400, epsilon=0.001000,  total reward:0.710000
# Game numer 15500, epsilon=0.001000,  total reward:0.700000
# Game numer 15600, epsilon=0.001000,  total reward:0.610000
# Game numer 15700, epsilon=0.001000,  total reward:0.590000
# Game numer 15800, epsilon=0.001000,  total reward:0.730000
# Game numer 15900, epsilon=0.001000,  total reward:0.690000
# Game numer 16000, epsilon=0.001000,  total reward:0.780000
# Game numer 16100, epsilon=0.001000,  total reward:0.790000
# Game numer 16200, epsilon=0.001000,  total reward:0.600000
# Game numer 16300, epsilon=0.001000,  total reward:0.740000
# Game numer 16400, epsilon=0.001000,  total reward:0.660000
# Game numer 16500, epsilon=0.001000,  total reward:0.740000
# Game numer 16600, epsilon=0.001000,  total reward:0.730000
# Game numer 16700, epsilon=0.001000,  total reward:0.730000
# Game numer 16800, epsilon=0.001000,  total reward:0.790000
# Game numer 16900, epsilon=0.001000,  total reward:0.740000
# Game numer 17000, epsilon=0.001000,  total reward:0.720000
# Game numer 17100, epsilon=0.001000,  total reward:0.580000
# Game numer 17200, epsilon=0.001000,  total reward:0.550000
# Game numer 17300, epsilon=0.001000,  total reward:0.780000
# Game numer 17400, epsilon=0.001000,  total reward:0.580000
# Game numer 17500, epsilon=0.001000,  total reward:0.670000
# Game numer 17600, epsilon=0.001000,  total reward:0.760000
# Game numer 17700, epsilon=0.001000,  total reward:0.740000
# Game numer 17800, epsilon=0.001000,  total reward:0.700000
# Game numer 17900, epsilon=0.001000,  total reward:0.800000
# Game numer 18000, epsilon=0.001000,  total reward:0.680000
# Game numer 18100, epsilon=0.001000,  total reward:0.580000
# Game numer 18200, epsilon=0.001000,  total reward:0.740000
# Game numer 18300, epsilon=0.001000,  total reward:0.800000
# Game numer 18400, epsilon=0.001000,  total reward:0.780000
# Game numer 18500, epsilon=0.001000,  total reward:0.690000
# Game numer 18600, epsilon=0.001000,  total reward:0.610000
# Game numer 18700, epsilon=0.001000,  total reward:0.730000
# Game numer 18800, epsilon=0.001000,  total reward:0.670000
# Game numer 18900, epsilon=0.001000,  total reward:0.800000
# Game numer 19000, epsilon=0.001000,  total reward:0.580000
# Game numer 19100, epsilon=0.001000,  total reward:0.630000
# Game numer 19200, epsilon=0.001000,  total reward:0.610000
# Game numer 19300, epsilon=0.001000,  total reward:0.760000
# Game numer 19400, epsilon=0.001000,  total reward:0.740000
# Game numer 19500, epsilon=0.001000,  total reward:0.750000
# Game numer 19600, epsilon=0.001000,  total reward:0.700000
# Game numer 19700, epsilon=0.001000,  total reward:0.700000
# Game numer 19800, epsilon=0.001000,  total reward:0.770000
# Game numer 19900, epsilon=0.001000,  total reward:0.610000
# [[4.72563104e-01 3.72665670e-01 3.78150772e-01 4.41362595e-01]
#  [1.09026081e-01 2.46878513e-01 3.42233316e-01 5.55584394e-01]
#  [2.97439414e-01 2.47127041e-01 2.34546897e-01 5.23060494e-01]
#  [1.39986844e-01 7.49587669e-02 2.32190239e-03 4.99769274e-01]
#  [5.14067283e-01 2.50510700e-01 1.26770882e-01 1.07492617e-01]
#  [6.80195147e-05 6.98881962e-06 8.28213306e-05 7.79682486e-06]
#  [1.89987672e-03 2.81727147e-04 1.82925739e-01 1.58491209e-03]
#  [2.53335290e-05 8.53179739e-05 8.39578114e-06 4.90978506e-06]
#  [1.73475930e-01 1.96155529e-01 2.52973239e-02 6.04724427e-01]
#  [1.67479075e-01 6.66510690e-01 1.44138610e-02 5.88409188e-02]
#  [7.41004780e-01 1.10342346e-01 3.24129735e-02 1.14865952e-02]
#  [1.65522189e-05 2.77649000e-06 9.70695996e-05 7.15228114e-05]
#  [7.50908402e-05 7.08843014e-05 9.41159714e-05 2.91452041e-06]
#  [2.29298164e-01 2.40059134e-01 7.59764805e-01 3.90926613e-01]
#  [5.57995171e-01 9.08370054e-01 4.40181156e-01 5.06358769e-01]
#  [1.39831530e-06 3.16944752e-05 4.25885418e-05 6.78702678e-05]]

# %% [markdown]
# We can now watch our little q-table playing the game, this time using *in policty* moves only:

# %%
env.reset()
env.render()
for step in range(max_steps):
    print ("t=%d " % (step))
    # Take the action (index) that have the maximum expected future reward given that state
    action = np.argmax(qtable[state,:])
    new_state, reward, done, info = env.step(action)
    if done:
        env.render()            
        # We print the number of step it took.
        print("Number of steps", step)
        break
    #else we move    
    state = new_state
    env.render()
# Out:
# SFFF
# FHFH
# FFFH
# HFFG
# t=0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=1
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=2
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=3
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=4
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=5
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=6
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=7
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=8
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# t=9
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=10
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=11
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# t=12
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# t=13
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# t=14
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Number of steps 14

# %% [markdown]
# Playing the parameters, we should be able to make an algortihm quite capable to play the game
